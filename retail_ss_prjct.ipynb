# %%
import pandas as pd

# %%
df=pd.read_csv("/content/retail_store_sales.csv")

# %%
df_backup=df.copy()

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3              NaN
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (12575, 11)

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                1213
# Price Per Unit       609
# Quantity             604
# Total Spent          604
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64

# %%
df=df.dropna(subset=['Item'])

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                   0
# Price Per Unit         0
# Quantity               0
# Total Spent            0
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    3783
# dtype: int64

# %%
df.shape
# Out:
# (11362, 11)

# %%
#if "Discount Applied" in df.columns:
df["Discount Applied"] = df["Discount Applied"].fillna("N/A")
# Out:
# /tmp/ipython-input-754812158.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Discount Applied"] = df["Discount Applied"].fillna("N/A")

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3   Not Applicable
# ...

# %%
df["Discount Applied"].replace("Not Applicable","N/A",inplace=True)
# Out:
# /tmp/ipython-input-3621358968.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Discount Applied"].replace("Not Applicable","N/A",inplace=True)
# /tmp/ipython-input-3621358968.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Discount Applied"].replace("Not Applicable","N/A",inplace=True)

# %%
df['Discount Applied'].replace('N/A','False',inplace=True)
# Out:
# /tmp/ipython-input-3239841626.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Discount Applied'].replace('N/A','False',inplace=True)
# /tmp/ipython-input-3239841626.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Discount Applied'].replace('N/A','False',inplace=True)

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3            False
# ...

# %%
df.tail()
# Out:
#       Transaction ID Customer ID    Category         Item  Price Per Unit  \
# 12570    TXN_9347481     CUST_18  Patisserie  Item_23_PAT            38.0
# 12571    TXN_4009414     CUST_03   Beverages   Item_2_BEV             6.5
# 12572    TXN_5306010     CUST_11    Butchers   Item_7_BUT            14.0
# 12573    TXN_5167298     CUST_04   Furniture   Item_7_FUR            14.0
# 12574    TXN_2407494     CUST_23        Food  Item_9_FOOD            17.0
#
#        Quantity  Total Spent Payment Method  Location Transaction Date  \
# 12570       4.0        152.0    Credit Card  In-store       2023-09-03
# 12571       9.0         58.5           Cash    Online       2022-08-12
# 12572      10.0        140.0           Cash    Online       2024-08-24
# 12573       6.0         84.0           Cash    Online       2023-12-30
# 12574       3.0         51.0           Cash    Online       2022-08-06
#
#       Discount Applied
# 12570            False
# 12571            False
# ...

# %%
df.describe()
# Out:
#        Price Per Unit      Quantity   Total Spent
# count    11362.000000  11362.000000  11362.000000
# mean        23.356847      5.535029    129.642537
# std         10.736030      2.855166     94.662368
# min          5.000000      1.000000      5.000000
# 25%         14.000000      3.000000     52.000000
# 50%         23.000000      6.000000    108.500000
# 75%         33.500000      8.000000    192.000000
# max         41.000000     10.000000    410.000000

# %%
df=df[df["Quantity"].notna()]

# %%
df['Quantity']
# Out:
# 0        10.0
# 1         9.0
# 2         2.0
# 3         9.0
# 4         7.0
#          ...
# 12570     4.0
# 12571     9.0
# 12572    10.0
# 12573     6.0
# 12574     3.0
# Name: Quantity, Length: 11362, dtype: float64

# %%
df.loc[df.Category=='Food']
# Out:
#       Transaction ID Customer ID Category          Item  Price Per Unit  \
# 4        TXN_4575373     CUST_05     Food   Item_6_FOOD            12.5
# 6        TXN_3652209     CUST_07     Food   Item_1_FOOD             5.0
# 12       TXN_5874772     CUST_23     Food   Item_2_FOOD             6.5
# 23       TXN_3314099     CUST_04     Food  Item_10_FOOD            18.5
# 28       TXN_1598860     CUST_08     Food  Item_14_FOOD            24.5
# ...              ...         ...      ...           ...             ...
# 12554    TXN_1434202     CUST_18     Food  Item_10_FOOD            18.5
# 12555    TXN_9743446     CUST_24     Food  Item_13_FOOD            23.0
# 12559    TXN_5604451     CUST_08     Food  Item_21_FOOD            35.0
# 12568    TXN_1096134     CUST_06     Food   Item_4_FOOD             9.5
# 12574    TXN_2407494     CUST_23     Food   Item_9_FOOD            17.0
#
#        Quantity  Total Spent  Payment Method  Location Transaction Date  \
# ...

# %%
df.loc[df['Payment Method']=="Credit Card"].head()
# Out:
#    Transaction ID Customer ID   Category         Item  Price Per Unit  \
# 2     TXN_9303719     CUST_02   Butchers  Item_12_BUT            21.5
# 3     TXN_9458126     CUST_06  Beverages  Item_16_BEV            27.5
# 6     TXN_3652209     CUST_07       Food  Item_1_FOOD             5.0
# 8     TXN_9728486     CUST_23  Furniture  Item_16_FUR            27.5
# 26    TXN_9057609     CUST_18   Butchers  Item_20_BUT            33.5
#
#     Quantity  Total Spent Payment Method  Location Transaction Date  \
# 2        2.0         43.0    Credit Card    Online       2022-10-05
# 3        9.0        247.5    Credit Card    Online       2022-05-07
# 6        8.0         40.0    Credit Card  In-store       2023-06-10
# 8        1.0         27.5    Credit Card  In-store       2023-04-26
# 26       4.0        134.0    Credit Card  In-store       2022-03-16
#
#    Discount Applied
# 2             False
# 3             False
# 6              True
# 8             False
# 26             True

# %%
df.loc[df['Payment Method']=="Cash"].head()
# Out:
#    Transaction ID Customer ID                       Category         Item  \
# 9     TXN_2722661     CUST_25                       Butchers  Item_22_BUT
# 10    TXN_8776416     CUST_22                       Butchers   Item_3_BUT
# 12    TXN_5874772     CUST_23                           Food  Item_2_FOOD
# 16    TXN_7563311     CUST_23                     Patisserie  Item_17_PAT
# 22    TXN_6547964     CUST_10  Electric household essentials   Item_4_EHE
#
#     Price Per Unit  Quantity  Total Spent Payment Method  Location  \
# 9             36.5       3.0        109.5           Cash    Online
# 10             8.0       9.0         72.0           Cash  In-store
# 12             6.5       7.0         45.5           Cash    Online
# 16            29.0       8.0        232.0           Cash    Online
# 22             9.5       7.0         66.5           Cash  In-store
#
#    Transaction Date Discount Applied
# 9        2024-03-14            False
# 10       2024-12-14             True
# ...

# %%
df["Total calc"] =df[ "Quantity"] * df ["Price Per Unit"]

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied  Total calc
# 0             True       185.0
# 1             True       261.0
# ...

# %%
df.drop("Total calc",axis=1,inplace=True)

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3            False
# ...

# %%
df.Category.value_counts()
# Out:
# Category
# Furniture                             1460
# Electric household essentials         1437
# Beverages                             1427
# Food                                  1426
# Milk Products                         1425
# Butchers                              1421
# Computers and electric accessories    1397
# Patisserie                            1369
# Name: count, dtype: int64

# %%
df.keys()
# Out:
# Index(['Transaction ID', 'Customer ID', 'Category', 'Item', 'Price Per Unit',
#        'Quantity', 'Total Spent', 'Payment Method', 'Location',
#        'Transaction Date', 'Discount Applied'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
df.groupby('Category')['Quantity'].mean().plot(kind='bar',color='Orange',hatch='/')
plt.xlabel('Category')
plt.xticks(rotation=80)
plt.ylabel('Quantity')
plt.title('Average Quantity by Category')
plt.tight_layout()
plt.show()

# %%
df.groupby('Price Per Unit')['Total Spent'].mean()
# Out:
# Price Per Unit
# 5.0      26.395062
# 6.5      35.691147
# 8.0      44.089888
# 9.5      51.314961
# 11.0     61.683544
# 12.5     69.173307
# 14.0     75.488834
# 15.5     83.083490
# 17.0     99.041139
# 18.5    100.180505
# 20.0    108.552413
# 21.5    120.334739
# 23.0    131.137860
# 24.5    137.151961
# 26.0    147.971370
# 27.5    153.871822
# 29.0    160.488636
# 30.5    176.720588
# 32.0    176.182232
# 33.5    185.311437
# 35.0    204.335260
# 36.5    197.579812
# 38.0    202.813953
# 39.5    223.580822
# 41.0    226.229537
# Name: Total Spent, dtype: float64

# %%
df.to_csv("Retail_Cleaned.csv", index=False)

# %%
print("Cleaned file saved as Retail_Cleaned.csv")
# Out:
# Cleaned file saved as Retail_Cleaned.csv
